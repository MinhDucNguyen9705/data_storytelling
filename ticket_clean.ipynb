# %%
import pandas as pd 
import numpy as np

# %%
ticket = pd.read_csv('ticket.csv')

# %%
ticket.head()
# Out:
#             orderid cashier   saledate    total  customerid  ticketcode  \
# 0  10006052019B0225  emp002   5/6/2019  90000.0  0000000014    20074925
# 1  10006052019B0225  emp002   5/6/2019  90000.0  0000000014    20074924
# 2  10022052019B0167  emp011  5/22/2019  90000.0  0000000034    20097042
# 3  10022052019B0167  emp011  5/22/2019  90000.0  0000000034    20097041
# 4  10130052019B0141  emp005  5/30/2019  90000.0  0000000034    20106761
#
#         date   time slot  room                                     film  \
# 0   5/6/2019  18:15  G04     3                        AVENGERS: HỒI KẾT
# 1   5/6/2019  18:15  G03     3                        AVENGERS: HỒI KẾT
# 2  5/22/2019  20:45  E04     2  JOHN WICK 3: CHUẨN BỊ CHIẾN TRANH (C18)
# 3  5/22/2019  20:45  E03     2  JOHN WICK 3: CHUẨN BỊ CHIẾN TRANH (C18)
# 4  5/30/2019  19:30  F04     1                   NGÔI ĐỀN KỲ QUÁI (C18)
#
#   slot type ticket type  ticket price popcorn
# 0       ĐƠN  Thành viên         45000   Không
# ...

# %%
ticket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35474 entries, 0 to 35473
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   orderid       35378 non-null  object
#  1   cashier       35474 non-null  object
#  2   saledate      35378 non-null  object
#  3   total         35378 non-null  float64
#  4   customerid    35474 non-null  object
#  5   ticketcode    35474 non-null  int64
#  6   date          35474 non-null  object
#  7   time          35474 non-null  object
#  8   slot          35474 non-null  object
#  9   room          35474 non-null  int64
#  10  film          35474 non-null  object
#  11  slot type     35474 non-null  object
#  12  ticket type   35474 non-null  object
#  13  ticket price  35474 non-null  int64
#  14  popcorn       35378 non-null  object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 4.1+ MB

# %%
ticket.sort_values(by='total', ascending=False)
# Out:
#                 orderid  cashier   saledate      total  customerid  \
# 8425   10026052019B0285   emp007  5/26/2019  1935000.0  0000029127
# 8458   10026052019B0285   emp007  5/26/2019  1935000.0  0000029127
# 8460   10026052019B0285   emp007  5/26/2019  1935000.0  0000029127
# 8461   10026052019B0285   emp007  5/26/2019  1935000.0  0000029127
# 8462   10026052019B0285   emp007  5/26/2019  1935000.0  0000029127
# ...                 ...      ...        ...        ...         ...
# 23102               NaN  Website        NaN        NaN  0003008617
# 23103               NaN  Website        NaN        NaN  0003008617
# 23106               NaN  Website        NaN        NaN  0003008617
# 23107               NaN  Website        NaN        NaN  0003008617
# 23108               NaN  Website        NaN        NaN  0003008617
#
#        ticketcode       date   time slot  room  \
# 8425     20102384  5/26/2019  20:20  E12     2
# 8458     20102363  5/26/2019  20:20  D04     2
# ...
