# %%
import pandas as pd 
import numpy as np

# %%
film = pd.read_csv('film.csv')

# %%
film.head()
# Out:
#   show_id                           title            director  \
# 0     s27             X-Men: Dark Phoenix       Simon Kinberg
# 1    s165       The Kid Who Would Be King         Joe Cornish
# 2    s194  Disney My Music Story: Perfume  Kentaro Takayanagi
# 3    s222  Disney My Music Story: Yoshiki  Kentaro Takayanagi
# 4    s241           Great Shark Chow Down       Mark Woodward
#
#                                                 cast  \
# 0  James McAvoy, Michael Fassbender, Jennifer Law...
# 1  Louis Ashbourne Serkis, Tom Taylor, Rebecca Fe...
# 2                        a-chan , KASHIYUKA , NOCCHi
# 3                                            YOSHIKI
# 4                                       Dan Nachtrab
#
#                          country  release_year rating duration  \
# 0          United States, Canada          2019  PG-13  115 min
# 1  United Kingdom, United States          2019     PG  121 min
# 2                            NaN          2019    NaN   53 min
# 3           United States, Japan          2019  TV-PG   48 min
# 4                            NaN          2019  TV-PG   45 min
#
#                                    listed_in  \
# 0  Action-Adventure, Family, Science Fiction
# 1    Action-Adventure, Coming of Age, Family
# 2           Biographical, Documentary, Music
# 3           Biographical, Documentary, Music
# 4              Animals & Nature, Documentary
#
#                                          description
# 0  When Jean Grey transforms into the Dark Phoeni...
# 1  When a kid discovers the legendary sword, Exca...
# 2  J-Pop band Perfume shares their passion for mu...
# 3  Yoshiki from â€œX Japanâ€ performs two Disney...
# 4  Great Shark Chow Down â€“ prepare for a feast ...

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       60 non-null     object
#  1   title         60 non-null     object
#  2   director      50 non-null     object
#  3   cast          54 non-null     object
#  4   country       53 non-null     object
#  5   release_year  60 non-null     int64
#  6   rating        59 non-null     object
#  7   duration      60 non-null     object
#  8   listed_in     60 non-null     object
#  9   description   60 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 4.8+ KB

# %%
film.isnull().sum()
# Out:
# show_id          0
# title            0
# director        10
# cast             6
# country          7
# release_year     0
# rating           1
# duration         0
# listed_in        0
# description      0
# dtype: int64

# %%
film[film['director'].isnull()]
# Out:
#    show_id                                      title director  \
# 5     s265                              Man vs. Shark      NaN
# 9     s313                   Oil Spill of The Century      NaN
# 12    s366  Star Wars: Galaxy's Edge-Adventure Awaits      NaN
# 13    s393                  Lost City of Machu Picchu      NaN
# 15    s440        Women Of Impact: Changing The World      NaN
# 27    s594         Marvel Rising: Battle of The Bands      NaN
# 37    s620              Marvel Rising: Chasing Ghosts      NaN
# 38    s621               Marvel Rising: Heart of Iron      NaN
# 42    s632                    Happy Birthday, Mickey!      NaN
# 53    s963     Marvel Studios: Expanding the Universe      NaN
#
#                                                  cast        country  \
# 5                     Jeremiah Sullivan, Dave Hoffman  United States
# 9                                       LoÃ¯ck Peyron            NaN
# 12  Neil Harris, Kaley Cuoco, Oscar Isaac, Sarah H...  United States
# 13                                      Craig Sechler  United States
# 15                                 Julianna Margulies  United States
# 27  Dee Baker, Dove Cameron, Skai Jackson, Kathree...  United States
# 37  Dee Baker, Chloe Bennet, Dove Cameron, Skai Ja...  United States
# 38  Dee Baker, Chloe Bennet, Dove Cameron, Robbie ...  United States
# 42                                                NaN            NaN
# 53                                                NaN            NaN
#
#     release_year    rating duration  \
# 5           2019     TV-PG   45 min
# 9           2019     TV-PG   45 min
# 12          2019     TV-PG   81 min
# 13          2019     TV-14   44 min
# 15          2019     TV-PG   44 min
# 27          2019     TV-Y7   23 min
# 37          2019  TV-Y7-FV   24 min
# 38          2019     TV-Y7   46 min
# 42          2019      TV-G    2 min
# 53          2019     TV-PG   13 min
#
#                                      listed_in  \
# 5                Animals & Nature, Documentary
# 9                      Documentary, Historical
# 12                         Documentary, Family
# 13                         Documentary, Family
# 15                     Documentary, Historical
# 27      Action-Adventure, Animation, Superhero
# 37      Action-Adventure, Animation, Superhero
# 38  Action-Adventure, Animation, Coming of Age
# 42                    Animation, Comedy, Dance
# 53                         Documentary, Family
#
#                                           description
# 5   Marine biologist attempts to get bitten by a d...
# 9   LoÃ¯ck Peyron investigates the 1978 Amoco Cadi...
# 12  Celebrating Disneyâ€™s new land that brings St...
# 13  Who were the mysterious people who built Machu...
# 15  How will you make the world a better place? He...
# 27  Gwen (Ghost-Spider) has to defeat Screaming Mi...
# 37    Ghost-Spider teams up with the Secret Warriors.
# 38  Ironheart joins the Secret Warriors to defend ...
# 42  Celebrating Mickey, the worldâ€™s most beloved...
# 53  An exciting look into the future of Marvel Stu...

# %%
film.loc[film['title']=='Oil Spill of The Century', 'director'] = "Josselin Mahot, Fabrice Gardel"
film.loc[film['title']=="Star Wars: Galaxy's Edge-Adventure Awaits", 'director'] = "Christian Lamb"
film.loc[film['title']=="Women Of Impact: Changing The World", 'director'] = 'Lisa Feit'
film.loc[film['title']=='Marvel Rising: Battle of The Bands', 'director'] = 'Chris Rutkowski'
film.loc[film['title']=='Marvel Rising: Chasing Ghosts', 'director'] = 'Alfred Gimeno'
film.loc[film['title']=='Marvel Rising: Heart of Iron', 'director'] = 'Sol Choi, Alfred Gimeno'
# source: IMDB

# %%
film[film['cast'].isnull()]
# Out:
#    show_id                                   title         director cast  \
# 35    s614                       One Day at Disney   Fritz Mitchell  NaN
# 42    s632                 Happy Birthday, Mickey!              NaN  NaN
# 49    s891                   Into the Grand Canyon     Pete McBride  NaN
# 51    s920                                 Kitbull  Rosana Sullivan  NaN
# 53    s963  Marvel Studios: Expanding the Universe              NaN  NaN
# 58   s1125                          Smash and Grab     Brian Larsen  NaN
#
#           country  release_year rating duration  \
# 35  United States          2019  TV-PG   62 min
# 42            NaN          2019   TV-G    2 min
# 49  United States          2019  TV-PG   82 min
# 51  United States          2019     PG    9 min
# 53            NaN          2019  TV-PG   13 min
# 58  United States          2019     PG    8 min
#
#                                           listed_in  \
# 35                              Documentary, Family
# 42                         Animation, Comedy, Dance
# 49  Action-Adventure, Animals & Nature, Documentary
# 51                         Animation, Buddy, Comedy
# 53                              Documentary, Family
# 58                         Animation, Buddy, Family
#
#                                           description
# 35  Discover the inspiring personal stories of the...
# 42  Celebrating Mickey, the worldâ€™s most beloved...
# 49  Two friends set out to traverse the Grand Cany...
# 51  An unlikely connection between a kitten and a ...
# 53  An exciting look into the future of Marvel Stu...
# 58  Two antiquated robots risk everything for free...

# %%
film['duration'] = film['duration'].apply(lambda x: int(x.split()[0]))

# %%
film.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       60 non-null     object
#  1   title         60 non-null     object
#  2   director      56 non-null     object
#  3   cast          54 non-null     object
#  4   country       53 non-null     object
#  5   release_year  60 non-null     int64
#  6   rating        59 non-null     object
#  7   duration      60 non-null     int64
#  8   listed_in     60 non-null     object
#  9   description   60 non-null     object
# dtypes: int64(2), object(8)
# memory usage: 4.8+ KB

# %%
film['rating'].value_counts()
# Out:
# rating
# TV-PG       20
# TV-G        13
# PG          12
# PG-13        4
# G            4
# TV-Y7        4
# TV-14        1
# TV-Y7-FV     1
# Name: count, dtype: int64

# %%
list_of_genres = []
for genres in list(film['listed_in'].unique()):
    for genre in genres.split(','):
        if genre.strip() not in list_of_genres:
            list_of_genres.append(genre.strip())

for genre in list_of_genres:
    film[genre] = film['listed_in'].str.contains(genre)

# %%
film.isnull().sum()
# Out:
# show_id             0
# title               0
# director            4
# cast                6
# country             7
# release_year        0
# rating              1
# duration            0
# listed_in           0
# description         0
# Action-Adventure    0
# Family              0
# Science Fiction     0
# Coming of Age       0
# Biographical        0
# Documentary         0
# Music               0
# Animals & Nature    0
# Historical          0
# Fantasy             0
# Animation           0
# Comedy              0
# Musical             0
# Drama               0
# Superhero           0
# Concert Film        0
# Dance               0
# Buddy               0
# dtype: int64

# %%
film.loc[film['title']=='Disney My Music Story: Perfume','rating'] = 'TV-14'

# from IMDB

# %%
film.isnull().sum()
# Out:
# show_id             0
# title               0
# director            4
# cast                6
# country             7
# release_year        0
# rating              0
# duration            0
# listed_in           0
# description         0
# Action-Adventure    0
# Family              0
# Science Fiction     0
# Coming of Age       0
# Biographical        0
# Documentary         0
# Music               0
# Animals & Nature    0
# Historical          0
# Fantasy             0
# Animation           0
# Comedy              0
# Musical             0
# Drama               0
# Superhero           0
# Concert Film        0
# Dance               0
# Buddy               0
# dtype: int64

# %%
film[film['country'].isnull()]
# Out:
#    show_id                                   title  \
# 2     s194          Disney My Music Story: Perfume
# 4     s241                   Great Shark Chow Down
# 7     s289                   Ultimate Viking Sword
# 9     s313                Oil Spill of The Century
# 14    s433                     Chasing the Equinox
# 42    s632                 Happy Birthday, Mickey!
# 53    s963  Marvel Studios: Expanding the Universe
#
#                           director                         cast country  \
# 2               Kentaro Takayanagi  a-chan , KASHIYUKA , NOCCHi     NaN
# 4                    Mark Woodward                 Dan Nachtrab     NaN
# 7                       Peter Yost                  Jay Sanders     NaN
# 9   Josselin Mahot, Fabrice Gardel                LoÃ¯ck Peyron     NaN
# 14                     Kenny Scott                 Stefan Frank     NaN
# 42                             NaN                          NaN     NaN
# 53                             NaN                          NaN     NaN
#
#     release_year rating  duration                         listed_in  \
# 2           2019  TV-14        53  Biographical, Documentary, Music
# 4           2019  TV-PG        45     Animals & Nature, Documentary
# 7           2019  TV-PG        45           Documentary, Historical
# 9           2019  TV-PG        45           Documentary, Historical
# 14          2019  TV-PG        45                       Documentary
# 42          2019   TV-G         2          Animation, Comedy, Dance
# 53          2019  TV-PG        13               Documentary, Family
#
#                                           description  ...  Historical  \
# 2   J-Pop band Perfume shares their passion for mu...  ...       False
# 4   Great Shark Chow Down â€“ prepare for a feast ...  ...       False
# 7   National Geographic reconstructs the Ulfberht,...  ...        True
# 9   LoÃ¯ck Peyron investigates the 1978 Amoco Cadi...  ...        True
# 14  Ancient civilizations shared an incredible kno...  ...       False
# 42  Celebrating Mickey, the worldâ€™s most beloved...  ...       False
# 53  An exciting look into the future of Marvel Stu...  ...       False
#
#     Fantasy  Animation  Comedy  Musical  Drama  Superhero  Concert Film  \
# 2     False      False   False    False  False      False         False
# 4     False      False   False    False  False      False         False
# 7     False      False   False    False  False      False         False
# 9     False      False   False    False  False      False         False
# 14    False      False   False    False  False      False         False
# 42    False       True    True    False  False      False         False
# 53    False      False   False    False  False      False         False
#
#     Dance  Buddy
# 2   False  False
# 4   False  False
# 7   False  False
# 9   False  False
# 14  False  False
# 42   True  False
# 53  False  False
#
# [7 rows x 28 columns]

# %%
film.loc[film['title'].isin(['Disney My Music Story: Perfume', 'Great Shark Chow Down', 'Marvel Studios: Expanding the Universe']),'country'] = 'United States'

# %%
film[film['country'].isnull()]
# Out:
#    show_id                     title                        director  \
# 7     s289     Ultimate Viking Sword                      Peter Yost
# 9     s313  Oil Spill of The Century  Josselin Mahot, Fabrice Gardel
# 14    s433       Chasing the Equinox                     Kenny Scott
# 42    s632   Happy Birthday, Mickey!                             NaN
#
#              cast country  release_year rating  duration  \
# 7     Jay Sanders     NaN          2019  TV-PG        45
# 9   LoÃ¯ck Peyron     NaN          2019  TV-PG        45
# 14   Stefan Frank     NaN          2019  TV-PG        45
# 42            NaN     NaN          2019   TV-G         2
#
#                    listed_in  \
# 7    Documentary, Historical
# 9    Documentary, Historical
# 14               Documentary
# 42  Animation, Comedy, Dance
#
#                                           description  ...  Historical  \
# 7   National Geographic reconstructs the Ulfberht,...  ...        True
# 9   LoÃ¯ck Peyron investigates the 1978 Amoco Cadi...  ...        True
# 14  Ancient civilizations shared an incredible kno...  ...       False
# 42  Celebrating Mickey, the worldâ€™s most beloved...  ...       False
#
#     Fantasy  Animation  Comedy  Musical  Drama  Superhero  Concert Film  \
# 7     False      False   False    False  False      False         False
# 9     False      False   False    False  False      False         False
# 14    False      False   False    False  False      False         False
# 42    False       True    True    False  False      False         False
#
#     Dance  Buddy
# 7   False  False
# 9   False  False
# 14  False  False
# 42   True  False
#
# [4 rows x 28 columns]

# %%
film[film['cast'].isnull()]
# Out:
#    show_id                                   title         director cast  \
# 35    s614                       One Day at Disney   Fritz Mitchell  NaN
# 42    s632                 Happy Birthday, Mickey!              NaN  NaN
# 49    s891                   Into the Grand Canyon     Pete McBride  NaN
# 51    s920                                 Kitbull  Rosana Sullivan  NaN
# 53    s963  Marvel Studios: Expanding the Universe              NaN  NaN
# 58   s1125                          Smash and Grab     Brian Larsen  NaN
#
#           country  release_year rating  duration  \
# 35  United States          2019  TV-PG        62
# 42            NaN          2019   TV-G         2
# 49  United States          2019  TV-PG        82
# 51  United States          2019     PG         9
# 53  United States          2019  TV-PG        13
# 58  United States          2019     PG         8
#
#                                           listed_in  \
# 35                              Documentary, Family
# 42                         Animation, Comedy, Dance
# 49  Action-Adventure, Animals & Nature, Documentary
# 51                         Animation, Buddy, Comedy
# 53                              Documentary, Family
# 58                         Animation, Buddy, Family
#
#                                           description  ...  Historical  \
# 35  Discover the inspiring personal stories of the...  ...       False
# 42  Celebrating Mickey, the worldâ€™s most beloved...  ...       False
# 49  Two friends set out to traverse the Grand Cany...  ...       False
# 51  An unlikely connection between a kitten and a ...  ...       False
# 53  An exciting look into the future of Marvel Stu...  ...       False
# 58  Two antiquated robots risk everything for free...  ...       False
#
#     Fantasy  Animation  Comedy  Musical  Drama  Superhero  Concert Film  \
# 35    False      False   False    False  False      False         False
# 42    False       True    True    False  False      False         False
# 49    False      False   False    False  False      False         False
# 51    False       True    True    False  False      False         False
# 53    False      False   False    False  False      False         False
# 58    False       True   False    False  False      False         False
#
#     Dance  Buddy
# 35  False  False
# 42   True  False
# 49  False  False
# 51  False   True
# 53  False  False
# 58  False   True
#
# [6 rows x 28 columns]

# %%
film.set_index('show_id').to_csv('film_cleaned.csv')
